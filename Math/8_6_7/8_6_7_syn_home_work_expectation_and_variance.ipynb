# %% [markdown]
# ### Математическое ожидание и дисперсия

# %% [markdown]
# #### Цель

# %% [markdown]
# Научиться определять математическое ожидание и разброс данных для дальнейшего применения в анализе, прогнозировании и для принятия оптимальных решений.

# %% [markdown]
# #### Задание

# %% [markdown]
# Найдите математическое ожидание и стандартное отклонение для заданных случайных величин.

# %% [markdown]
# 1.
# \[
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# x & 25 & 10 & 27 & 3 & 1 \\
# \hline
# p & 0.09 & 0.16 & 0.2 & 0.16 & 0.2 \\
# \hline
# \end{array}
# \]
#
#
# 2.
# \[
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# x & 10 & 14 & 13 & 17 & 12 \\
# \hline
# p & 0.14 & 0.25 & 0.07 & 0.11 & 0.21 \\
# \hline
# \end{array}
# \]
#
# 3.
# \[
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# x & 24 & 7 & 9 & 15 & 1 \\
# \hline
# p & 0.05 & 0.27 & 0.05 & 0.18 & 0.09 \\
# \hline
# \end{array}
# \]
#
# 4.
# \[
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# x & 20 & 15 & 1 & 4 & 3 \\
# \hline
# p & 0.17 & 0.07 & 0.07 & 0.17 & 0.24 \\
# \hline
# \end{array}
# \]
#
# 5.
# \[
# \begin{array}{|c|c|c|c|c|c|}
# \hline
# x & 16 & 14 & 1 & 17 & 21 \\
# \hline
# p & 0.14 & 0.25 & 0.11 & 0.14 & 0.04 \\
# \hline
# \end{array}
# \]

# %% [markdown]
# #### Результат

# %% [markdown]
# Решение для задания предоставляется в виде прикрепленного фото с подробными ответами.

# %% [markdown]
# ![Screenshot from 2025-04-22 08-04-53.png](<attachment:Screenshot from 2025-04-22 08-04-53.png>) ![Screenshot from 2025-04-22 08-05-33.png](<attachment:Screenshot from 2025-04-22 08-05-33.png>) ![Screenshot from 2025-04-22 08-06-07.png](<attachment:Screenshot from 2025-04-22 08-06-07.png>) ![Screenshot from 2025-04-22 08-06-37.png](<attachment:Screenshot from 2025-04-22 08-06-37.png>) ![Screenshot from 2025-04-22 08-07-00.png](<attachment:Screenshot from 2025-04-22 08-07-00.png>) ![Screenshot from 2025-04-22 08-07-36.png](<attachment:Screenshot from 2025-04-22 08-07-36.png>) ![Screenshot from 2025-04-22 08-07-56.png](<attachment:Screenshot from 2025-04-22 08-07-56.png>) ![Screenshot from 2025-04-22 08-08-25.png](<attachment:Screenshot from 2025-04-22 08-08-25.png>) ![Screenshot from 2025-04-22 08-08-46.png](<attachment:Screenshot from 2025-04-22 08-08-46.png>) ![Screenshot from 2025-04-22 08-09-12.png](<attachment:Screenshot from 2025-04-22 08-09-12.png>)

# %% [markdown]
# #### Критерии оценивания

# %% [markdown]
# К1 - за  каждый правильно решенный пункт задания (+ 1 балл)
#
# Максимальное количество баллов —  5 баллов.
#
# Минимальное количество баллов, чтобы преподаватель смог зачесть вашу работу — 3 балла.
